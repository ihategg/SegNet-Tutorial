# %% [markdown]
# <a href="https://colab.research.google.com/github/ihategg/SegNet-Tutorial/blob/master/first_try.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import matplotlib as plt
from PIL import Image

# %%
path = "./dog.jpg"
pic = Image.open(path)
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x7F66DCA695D0>

# %%
pic_array = np.array(pic)
pic_array.shape
# Out:
# (300, 300, 3)
